// %% [markdown]
//  # Java template for Colaboratory notebooks

// %%
!apt update -q
!apt-get install -q openjdk-11-jdk-headless
!curl -L https://github.com/SpencerPark/IJava/releases/download/v1.3.0/ijava-1.3.0.zip -o ijava-kernel.zip
!unzip -q ijava-kernel.zip -d ijava-kernel && cd ijava-kernel && python3 install.py --sys-prefix
!jupyter kernelspec list

// %%
byte b0 = 122; byte b1 = 14;
 
(b0 + b1);

//Obtenemos la suma de las dos variables, se obtiene ese resultado por la suma de las variables y es un de tipo (int) el resultado

// %%
char c = 'a';
int n= c;

//No se obtiene nada debido a que las variables tienen valores distintos de tipo (int) y (char)

// %%
char c = 'a';
int n= c;
short s = c;

//Es diferente debido a que salta error debido a que son incompatible el (chart) y el (short).

// %%
char c = 'a';
int n= c;
short s = (short)c;

// %%
short s = (short)32000;
short s = (short)35000;

//No tiene resultado debido a la falta de declaracion de variable de resultado y su impresion.
